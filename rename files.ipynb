# %%
import os

# %%
dirs = os.listdir(path=r'C:\Users\User\Pictures\ПРАБО\НОВЫЙ САЙТ\temp')
dirs
# Out:
# ['006(1)',
#  '007(1)',
#  '023(1)',
#  '025(1)',
#  '03f(1)',
#  '043(1)',
#  '047(1)',
#  '04a(1)',
#  '04b(1)',
#  '04d(1)',
#  '055(1)',
#  '056(1)',
#  '060(1)',
#  '062(1)',
#  '066(1)',
#  '072(1)',
#  '078(1)',
#  '07b(1)',
#  '07d(1)',
#  '086(1)',
#  '090(1)',
#  '092(1)',
#  '097(1)',
#  '09b(1)',
#  '107(1)',
#  '127(1)',
#  '141(1)',
#  '161(1)',
#  '16b(1)',
#  '17b(1)',
#  '17d(1)',
#  '17e(1)',
#  '193(1)',
#  '195(1)',
#  '19b(1)',
#  '19f(1)',
#  '207(1)',
#  '20c(1)',
#  '220(1)',
#  '22e(1)',
#  '251(1)',
#  '25a(1)',
#  '26d(1)',
#  '277(1)',
#  '27c(1)',
#  '27e(1)',
#  '2e3(1)',
#  '2e7(1)',
#  '2f3(1)',
#  '2f8(1)',
#  '2fb(1)',
#  '30d(1)',
#  '31f(1)',
#  '338(1)',
#  '33f(1)',
#  '349(1)',
#  '35f(1)',
#  '365(1)',
#  '366(1)',
#  '37e(1)',
#  '38a(1)',
#  '38f(1)',
#  '393(1)',
#  '39b(1)',
#  '3b5(1)',
#  '3c6(1)',
#  '405(1)',
#  '408(1)',
#  '411(1)',
#  '43e(1)',
#  '44b(1)',
#  '46f(1)',
#  '474(1)',
#  '47b(1)',
#  '490(1)',
#  '4a5(1)',
# ...

# %%
dirs[0][0:3]
# Out:
# '006'

# %%
rename_dirs = []
for i in range(len(dirs)):
    rename_dirs.append(dirs[i][0:3])
rename_dirs
# Out:
# ['006',
#  '007',
#  '023',
#  '025',
#  '03f',
#  '043',
#  '047',
#  '04a',
#  '04b',
#  '04d',
#  '055',
#  '056',
#  '060',
#  '062',
#  '066',
#  '072',
#  '078',
#  '07b',
#  '07d',
#  '086',
#  '090',
#  '092',
#  '097',
#  '09b',
#  '107',
#  '127',
#  '141',
#  '161',
#  '16b',
#  '17b',
#  '17d',
#  '17e',
#  '193',
#  '195',
#  '19b',
#  '19f',
#  '207',
#  '20c',
#  '220',
#  '22e',
#  '251',
#  '25a',
#  '26d',
#  '277',
#  '27c',
#  '27e',
#  '2e3',
#  '2e7',
#  '2f3',
#  '2f8',
#  '2fb',
#  '30d',
#  '31f',
#  '338',
#  '33f',
#  '349',
#  '35f',
#  '365',
#  '366',
#  '37e',
#  '38a',
#  '38f',
#  '393',
#  '39b',
#  '3b5',
#  '3c6',
#  '405',
#  '408',
#  '411',
#  '43e',
#  '44b',
#  '46f',
#  '474',
#  '47b',
#  '490',
#  '4a5',
#  '4c3',
#  '4c4',
#  '4cb',
#  '4d2',
#  '509',
#  '515',
#  '51b',
#  '524',
#  '539',
#  '540',
#  '558',
#  '563',
#  '56d',
#  '580',
#  '59a',
#  '5a5',
#  '5ac',
#  '5bf',
#  '5c2',
#  '5c7',
#  '5d0',
#  '5d4',
#  '5df',
#  '5fd',
# ...

# %%
for j in range(len(dirs)):
    os.rename(dirs[j], rename_dirs[j])

# %%
os.chdir('C:\\Users\\User\\Pictures\\temp')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User\\Pictures\\temp'
